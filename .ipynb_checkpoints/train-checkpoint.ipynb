# %% [markdown]
# # Requirements
# pandas >= 0.20

# %%
import os
import pandas as pd 
import numpy as np
import re
from IPython.display import display
pd.set_option('display.max_rows', 500)
pd.options.display.max_columns = None

# %% [markdown]
# ## Let us write some functions to create a ML pipeline which will do below tasks -
# ### 1. Read CSV raw file and create a Pandas DataFrame
# ### 2. Feature Extraction - Handling missing values, retrieving best features from the data, normalizing features and addressing class imbalance of labels. This will enable us to create a ML ready dataset
# ### 3. Training a Classifier - Grid search, K-fold cross-validation, Naive Bayes algorithm to predict 5 year future plan

# %%
# Read CSV raw file
def read_data(path,csv_filename):
    """
    Takes 2 parameters as input
    
    1.path : path to the folder where CSV file resides
    2.file_name : name of the file
    """
    print("Inside read data\n")
    # set working directory, to easily read the CSV data 
    os.chdir(path)
    print("Working directory set to :: " + str(os.getcwd()))
    input = pd.read_csv(csv_filename, error_bad_lines = False)
    return input

# %%
df = read_data(r"C:\Users\prana\Desktop\stack_overflow_data","survey_results_public.csv")
# Below line might give low_memory Warning because Pandas tries to
# infer the datatypes of columns by reading all rows.
df.head(5)
# Out:
# Inside read data
#
# Working directory set to :: C:\Users\prana\Desktop\stack_overflow_data
# c:\users\prana\appdata\local\programs\python\python35-32\lib\site-packages\IPython\core\interactiveshell.py:2850: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType       YearsCoding  \
# 0                               Full-stack developer         3-5 years
# 1  Database administrator;DevOps specialist;Full-...  30 or more years
# 2           Engineering manager;Full-stack developer       24-26 years
# 3                               Full-stack developer       18-20 years
# 4  Data or business analyst;Desktop or enterprise...         6-8 years
#
#   YearsCodingProf                     JobSatisfaction  \
# 0       3-5 years                 Extremely satisfied
# 1     18-20 years             Moderately dissatisfied
# 2       6-8 years                Moderately satisfied
# 3     12-14 years  Neither satisfied nor dissatisfied
# 4       0-2 years                  Slightly satisfied
#
#                    CareerSatisfaction  \
# 0                 Extremely satisfied
# 1  Neither satisfied nor dissatisfied
# 2                Moderately satisfied
# 3               Slightly dissatisfied
# 4                Moderately satisfied
#
#                                        HopeFiveYears  \
# 0  Working as a founder or co-founder of my own c...
# 1  Working in a different or more specialized tec...
# 2  Working as a founder or co-founder of my own c...
# 3  Working as a founder or co-founder of my own c...
# 4  Working in a different or more specialized tec...
#
#                                      JobSearchStatus  \
# 0  I’m not actively looking, but I am open to new...
# 1                    I am actively looking for a job
# 2  I’m not actively looking, but I am open to new...
# 3  I’m not actively looking, but I am open to new...
# 4  I’m not actively looking, but I am open to new...
#
#                   LastNewJob  AssessJob1  AssessJob2  AssessJob3  AssessJob4  \
# 0       Less than a year ago        10.0         7.0         8.0         1.0
# 1      More than 4 years ago         1.0         7.0        10.0         8.0
# 2       Less than a year ago         NaN         NaN         NaN         NaN
# 3       Less than a year ago         NaN         NaN         NaN         NaN
# 4  Between 1 and 2 years ago         8.0         5.0         7.0         1.0
#
#    AssessJob5  AssessJob6  AssessJob7  AssessJob8  AssessJob9  AssessJob10  \
# 0         2.0         5.0         3.0         4.0         9.0          6.0
# 1         2.0         5.0         4.0         3.0         6.0          9.0
# 2         NaN         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN         NaN          NaN
# 4         2.0         6.0         4.0         3.0        10.0          9.0
#
#    AssessBenefits1  AssessBenefits2  AssessBenefits3  AssessBenefits4  \
# 0              NaN              NaN              NaN              NaN
# 1              1.0              5.0              3.0              7.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              1.0             10.0              2.0              4.0
#
#    AssessBenefits5  AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# 0              NaN              NaN              NaN              NaN
# 1             10.0              4.0             11.0              9.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              8.0              3.0             11.0              7.0
#
#    AssessBenefits9  AssessBenefits10  AssessBenefits11  JobContactPriorities1  \
# 0              NaN               NaN               NaN                    3.0
# 1              6.0               2.0               8.0                    3.0
# 2              NaN               NaN               NaN                    NaN
# 3              NaN               NaN               NaN                    NaN
# 4              5.0               9.0               6.0                    2.0
#
#    JobContactPriorities2  JobContactPriorities3  JobContactPriorities4  \
# 0                    1.0                    4.0                    2.0
# 1                    1.0                    5.0                    2.0
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    1.0                    4.0                    5.0
#
#    JobContactPriorities5  JobEmailPriorities1  JobEmailPriorities2  \
# 0                    5.0                  5.0                  6.0
# 1                    4.0                  1.0                  3.0
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    3.0                  7.0                  3.0
#
#    JobEmailPriorities3  JobEmailPriorities4  JobEmailPriorities5  \
# 0                  7.0                  2.0                  1.0
# 1                  4.0                  5.0                  2.0
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  6.0                  2.0                  1.0
#
#    JobEmailPriorities6  JobEmailPriorities7  \
# 0                  4.0                  3.0
# 1                  6.0                  7.0
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  4.0                  5.0
#
#                                          UpdateCV  \
# 0  My job status or other personal status changed
# 1               I saw an employer’s advertisement
# 2                                             NaN
# 3                        A recruiter contacted me
# 4  My job status or other personal status changed
#
#                       Currency  Salary SalaryType  ConvertedSalary  \
# 0                          NaN     NaN    Monthly              NaN
# 1  British pounds sterling (£)   51000     Yearly          70841.0
# 2                          NaN     NaN        NaN              NaN
# 3             U.S. dollars ($)     NaN        NaN              NaN
# 4      South African rands (R)  260000     Yearly          21426.0
#
#   CurrencySymbol                                 CommunicationTools  \
# 0            KES                                              Slack
# 1            GBP  Confluence;Office / productivity suite (Micros...
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            ZAR  Office / productivity suite (Microsoft Office,...
#
#    TimeFullyProductive                                     EducationTypes  \
# 0  One to three months  Taught yourself a new language, framework, or ...
# 1  One to three months  Taught yourself a new language, framework, or ...
# 2                  NaN                                                NaN
# 3  Three to six months  Completed an industry certification program (e...
# 4  Three to six months  Taken a part-time in-person course in programm...
#
#                                      SelfTaughtTypes TimeAfterBootcamp  \
# 0  The official documentation and/or standards fo...               NaN
# 1  The official documentation and/or standards fo...               NaN
# 2                                                NaN               NaN
# 3  The official documentation and/or standards fo...               NaN
# 4  The official documentation and/or standards fo...               NaN
#
#                    HackathonReasons  AgreeDisagree1  AgreeDisagree2  \
# 0  To build my professional network  Strongly agree  Strongly agree
# 1                               NaN           Agree           Agree
# 2                               NaN             NaN             NaN
# 3                               NaN        Disagree        Disagree
# 4                               NaN  Strongly agree           Agree
#
#                AgreeDisagree3  \
# 0  Neither Agree nor Disagree
# 1  Neither Agree nor Disagree
# 2                         NaN
# 3           Strongly disagree
# 4           Strongly disagree
#
#                                  LanguageWorkedWith  \
# 0                        JavaScript;Python;HTML;CSS
# 1                      JavaScript;Python;Bash/Shell
# 2                                               NaN
# 3  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4                C;C++;Java;Matlab;R;SQL;Bash/Shell
#
#                              LanguageDesireNextYear  \
# 0                        JavaScript;Python;HTML;CSS
# 1                                         Go;Python
# 2                                               NaN
# 3  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4              Assembly;C;C++;Matlab;SQL;Bash/Shell
#
#                                   DatabaseWorkedWith  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                         Redis;PostgreSQL;Memcached
# 2                                                NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4               SQL Server;PostgreSQL;Oracle;IBM Db2
#
#                               DatabaseDesireNextYear  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                                         PostgreSQL
# 2                                                NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                          PostgreSQL;Oracle;IBM Db2
#
#                   PlatformWorkedWith             PlatformDesireNextYear  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2                                NaN                                NaN
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   FrameworkWorkedWith  FrameworkDesireNextYear  \
# 0        Django;React             Django;React
# 1              Django                    React
# 2                 NaN                      NaN
# 3                 NaN  Angular;.NET Core;React
# 4                 NaN                      NaN
#
#                                           IDE OperatingSystem NumberMonitors  \
# 0               Komodo;Vim;Visual Studio Code     Linux-based              1
# 1          IPython / Jupyter;Sublime Text;Vim     Linux-based              2
# 2                                         NaN             NaN            NaN
# 3            Visual Studio;Visual Studio Code         Windows              2
# 4  Notepad++;Visual Studio;Visual Studio Code         Windows              2
#
#                                          Methodology     VersionControl  \
# 0                                        Agile;Scrum                Git
# 1                                                NaN     Git;Subversion
# 2                                                NaN                NaN
# 3                                 Agile;Kanban;Scrum                Git
# 4  Evidence-based software engineering;Formal sta...  Zip file back-ups
#
#                        CheckInCode AdBlocker AdBlockerDisable  \
# 0           Multiple times per day       Yes               No
# 1             A few times per week       Yes              Yes
# 2                              NaN       NaN              NaN
# 3           Multiple times per day       Yes              Yes
# 4  Weekly or a few times per month        No              NaN
#
#                                     AdBlockerReasons  \
# 0                                                NaN
# 1  The website I was visiting asked me to disable it
# 2                                                NaN
# 3  The ad-blocking software was causing display i...
# 4                                                NaN
#
#             AdsAgreeDisagree1           AdsAgreeDisagree2  \
# 0              Strongly agree              Strongly agree
# 1              Somewhat agree  Neither agree nor disagree
# 2                         NaN                         NaN
# 3  Neither agree nor disagree              Somewhat agree
# 4              Somewhat agree              Somewhat agree
#
#             AdsAgreeDisagree3  \
# 0              Strongly agree
# 1  Neither agree nor disagree
# 2                         NaN
# 3              Somewhat agree
# 4           Somewhat disagree
#
#                                           AdsActions  AdsPriorities1  \
# 0  Saw an online advertisement and then researche...             1.0
# 1                                                NaN             3.0
# 2                                                NaN             NaN
# 3  Stopped going to a website because of their ad...             NaN
# 4  Clicked on an online advertisement;Saw an onli...             2.0
#
#    AdsPriorities2  AdsPriorities3  AdsPriorities4  AdsPriorities5  \
# 0             5.0             4.0             7.0             2.0
# 1             5.0             1.0             4.0             6.0
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             3.0             4.0             6.0             1.0
#
#    AdsPriorities6  AdsPriorities7  \
# 0             6.0             3.0
# 1             7.0             2.0
# 2             NaN             NaN
# 3             NaN             NaN
# 4             7.0             5.0
#
#                                          AIDangerous  \
# 0  Artificial intelligence surpassing human intel...
# 1                      Increasing automation of jobs
# 2                                                NaN
# 3  Artificial intelligence surpassing human intel...
# 4              Algorithms making important decisions
#
#                                        AIInteresting  \
# 0              Algorithms making important decisions
# 1                      Increasing automation of jobs
# 2                                                NaN
# 3  Artificial intelligence surpassing human intel...
# 4              Algorithms making important decisions
#
#                                   AIResponsible  \
# 0  The developers or the people creating the AI
# 1  The developers or the people creating the AI
# 2                                           NaN
# 3       A governmental or other regulatory body
# 4  The developers or the people creating the AI
#
#                                             AIFuture           EthicsChoice  \
# 0  I'm excited about the possibilities more than ...                     No
# 1  I'm excited about the possibilities more than ...  Depends on what it is
# 2                                                NaN                    NaN
# 3  I don't care about it, or I haven't thought ab...                     No
# 4  I'm excited about the possibilities more than ...                     No
#
#                        EthicsReport  \
# 0                 Yes, and publicly
# 1             Depends on what it is
# 2                               NaN
# 3  Yes, but only within the company
# 4  Yes, but only within the company
#
#                               EthicsResponsible EthicalImplications  \
# 0  Upper management at the company/organization                 Yes
# 1  Upper management at the company/organization                 Yes
# 2                                           NaN                 NaN
# 3  Upper management at the company/organization                 Yes
# 4  Upper management at the company/organization                 Yes
#
#   StackOverflowRecommend               StackOverflowVisit  \
# 0       10 (Very Likely)           Multiple times per day
# 1       10 (Very Likely)  A few times per month or weekly
# 2                    NaN                              NaN
# 3       10 (Very Likely)             A few times per week
# 4       10 (Very Likely)            Daily or almost daily
#
#   StackOverflowHasAccount                           StackOverflowParticipate  \
# 0                     Yes  I have never participated in Q&A on Stack Over...
# 1                     Yes                    A few times per month or weekly
# 2                     NaN                                                NaN
# 3                     Yes                    A few times per month or weekly
# 4                     Yes                Less than once per month or monthly
#
#                                    StackOverflowJobs  \
# 0  No, I knew that Stack Overflow had a jobs boar...
# 1                                                Yes
# 2                                                NaN
# 3                                                Yes
# 4  No, I knew that Stack Overflow had a jobs boar...
#
#                         StackOverflowDevStory StackOverflowJobsRecommend  \
# 0                                         Yes                        NaN
# 1         No, I have one but it's out of date                          7
# 2                                         NaN                        NaN
# 3         No, I have one but it's out of date                          8
# 4  No, I know what it is but I don't have one                        NaN
#
#   StackOverflowConsiderMember       HypotheticalTools1  \
# 0                         Yes     Extremely interested
# 1                         Yes  A little bit interested
# 2                         NaN                      NaN
# 3                         Yes      Somewhat interested
# 4                         Yes     Extremely interested
#
#         HypotheticalTools2       HypotheticalTools3       HypotheticalTools4  \
# 0     Extremely interested     Extremely interested     Extremely interested
# 1  A little bit interested  A little bit interested  A little bit interested
# 2                      NaN                      NaN                      NaN
# 3      Somewhat interested      Somewhat interested      Somewhat interested
# 4     Extremely interested     Extremely interested     Extremely interested
#
#         HypotheticalTools5                WakeTime  HoursComputer  \
# 0     Extremely interested  Between 5:00 - 6:00 AM   9 - 12 hours
# 1  A little bit interested  Between 6:01 - 7:00 AM    5 - 8 hours
# 2                      NaN                     NaN            NaN
# 3      Somewhat interested  Between 6:01 - 7:00 AM   9 - 12 hours
# 4     Extremely interested          Before 5:00 AM  Over 12 hours
#
#            HoursOutside             SkipMeals             ErgonomicDevices  \
# 0           1 - 2 hours                 Never                Standing desk
# 1       30 - 59 minutes                 Never  Ergonomic keyboard or mouse
# 2                   NaN                   NaN                          NaN
# 3  Less than 30 minutes  3 - 4 times per week                          NaN
# 4           1 - 2 hours                 Never                          NaN
#
#                      Exercise Gender         SexualOrientation  \
# 0        3 - 4 times per week   Male  Straight or heterosexual
# 1   Daily or almost every day   Male  Straight or heterosexual
# 2                         NaN    NaN                       NaN
# 3  I don't typically exercise   Male  Straight or heterosexual
# 4        3 - 4 times per week   Male  Straight or heterosexual
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
#
#                   RaceEthnicity                Age Dependents MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes        NaN
# 1  White or of European descent  35 - 44 years old        Yes        NaN
# 2                           NaN                NaN        NaN        NaN
# 3  White or of European descent  35 - 44 years old         No         No
# 4  White or of European descent  18 - 24 years old        Yes        NaN
#
#                           SurveyTooLong     SurveyEasy
# 0  The survey was an appropriate length      Very easy
# 1  The survey was an appropriate length  Somewhat easy
# 2                                   NaN            NaN
# 3  The survey was an appropriate length  Somewhat easy
# 4  The survey was an appropriate length  Somewhat easy

# %%
# check dataframe stats and info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Columns: 129 entries, Respondent to SurveyEasy
# dtypes: float64(41), int64(1), object(87)
# memory usage: 64.5+ MB

# %%
# To check count of records in pandas use df.shape
# df.count counts rows for all non-NA rows
print("Rows in the data :: " + str(df.shape[0]))
print("Columns in the data :: " + str(df.shape[1]))
# Out:
# Rows in the data :: 98855
# Columns in the data :: 129

# %% [markdown]
# #### Function to display missing values and percentage of missing values from the input data

# %%
def missing_values(df):
    """
    Takes input as dataframe and prints all the columns with missing values.
    Also prints the percentage of missing values from the dataset.
    """
    null_df = pd.DataFrame(df.isna().sum()).reset_index()
    null_df = null_df.rename(columns={'index':'column_name' , 0 : 'missing_values'})
    null_df['percentage_missing'] = 100* null_df.missing_values / df.shape[0]
    null_df = null_df.sort_values('percentage_missing', ascending=False)
    display(null_df)

# %%
# function call to see missing values in dataset
missing_values(df)
# Out:
#                      column_name  missing_values  percentage_missing
# 60             TimeAfterBootcamp           92203           93.270952
# 126                   MilitaryUS           83074           84.036215
# 61              HackathonReasons           73164           74.011431
# 118             ErgonomicDevices           64797           65.547519
# 81              AdBlockerReasons           61110           61.817814
# 107   StackOverflowJobsRecommend           60538           61.239189
# 45           JobEmailPriorities3           52642           53.251732
# 43           JobEmailPriorities1           52642           53.251732
# 44           JobEmailPriorities2           52642           53.251732
# 49           JobEmailPriorities7           52642           53.251732
# 48           JobEmailPriorities6           52642           53.251732
# 47           JobEmailPriorities5           52642           53.251732
# 46           JobEmailPriorities4           52642           53.251732
# 54               ConvertedSalary           51153           51.745486
# 41         JobContactPriorities4           50149           50.729857
# 42         JobContactPriorities5           50149           50.729857
# 40         JobContactPriorities3           50149           50.729857
# 38         JobContactPriorities1           50149           50.729857
# 39         JobContactPriorities2           50149           50.729857
# 52                        Salary           48277           48.836174
# 53                    SalaryType           47785           48.338476
# 71           FrameworkWorkedWith           47235           47.782105
# 57           TimeFullyProductive           46983           47.527186
# 80              AdBlockerDisable           43957           44.466137
# 72       FrameworkDesireNextYear           43637           44.142431
# 56            CommunicationTools           41885           42.370138
# 59               SelfTaughtTypes           41501           41.981690
# 123                RaceEthnicity           41382           41.861312
# 68        DatabaseDesireNextYear           41357           41.836022
# 55                CurrencySymbol           40205           40.670679
# 76                   Methodology           39874           40.335845
# 85                    AdsActions           39341           39.796672
# 121            SexualOrientation           39090           39.542765
# 87                AdsPriorities2           38376           38.820495
# 91                AdsPriorities6           38376           38.820495
# 90                AdsPriorities5           38376           38.820495
# 89                AdsPriorities4           38376           38.820495
# 88                AdsPriorities3           38376           38.820495
# 92                AdsPriorities7           38376           38.820495
# 86                AdsPriorities1           38376           38.820495
# 70        PlatformDesireNextYear           37502           37.936371
# 122             EducationParents           37042           37.471043
# 51                      Currency           36847           37.273785
# 125                   Dependents           36259           36.678974
# 93                   AIDangerous           35740           36.153963
# 120                       Gender           34386           34.784280
# 99             EthicsResponsible           34315           34.712458
# 124                          Age           34281           34.678064
# 37              AssessBenefits11           33938           34.331091
# 32               AssessBenefits6           33937           34.330079
# 27               AssessBenefits1           33937           34.330079
# 28               AssessBenefits2           33937           34.330079
# 29               AssessBenefits3           33937           34.330079
# 30               AssessBenefits4           33937           34.330079
# 31               AssessBenefits5           33937           34.330079
# 34               AssessBenefits8           33937           34.330079
# 36              AssessBenefits10           33937           34.330079
# 35               AssessBenefits9           33937           34.330079
# 33               AssessBenefits7           33937           34.330079
# 94                 AIInteresting           33488           33.875879
# 50                      UpdateCV           33316           33.701887
# 95                 AIResponsible           33302           33.687724
# 106        StackOverflowDevStory           33178           33.562288
# 104     StackOverflowParticipate           33115           33.498558
# 128                   SurveyEasy           32976           33.357949
# 127                SurveyTooLong           32914           33.295230
# 69            PlatformWorkedWith           32856           33.236559
# 67            DatabaseWorkedWith           32585           32.962420
# 25                    AssessJob9           31870           32.239138
# 17                    AssessJob1           31870           32.239138
# 18                    AssessJob2           31870           32.239138
# 19                    AssessJob3           31870           32.239138
# 20                    AssessJob4           31870           32.239138
# 21                    AssessJob5           31870           32.239138
# 22                    AssessJob6           31870           32.239138
# 23                    AssessJob7           31870           32.239138
# 26                   AssessJob10           31870           32.239138
# 24                    AssessJob8           31870           32.239138
# 58                EducationTypes           30895           31.252845
# 62                AgreeDisagree1           30638           30.992868
# 63                AgreeDisagree2           30509           30.862374
# 64                AgreeDisagree3           30491           30.844166
# 12               JobSatisfaction           29579           29.921602
# 100          EthicalImplications           29546           29.888220
# 96                      AIFuture           29127           29.464367
# 112           HypotheticalTools4           28869           29.203379
# 111           HypotheticalTools3           28856           29.190228
# 113           HypotheticalTools5           28810           29.143695
# 110           HypotheticalTools2           28803           29.136614
# 109           HypotheticalTools1           28787           29.120429
# 98                  EthicsReport           28429           28.758282
# 97                  EthicsChoice           28073           28.398159
# 8                    CompanySize           27324           27.640484
# 117                    SkipMeals           26909           27.220677
# 116                 HoursOutside           26831           27.141773
# 119                     Exercise           26747           27.056800
# 115                HoursComputer           26722           27.031511
# 114                     WakeTime           26709           27.018360
# 78                   CheckInCode           26500           26.806939
# 66        LanguageDesireNextYear           25611           25.907643
# 77                VersionControl           24557           24.841434
# 83             AdsAgreeDisagree2           24442           24.725102
# 84             AdsAgreeDisagree3           24441           24.724091
# 82             AdsAgreeDisagree1           24370           24.652268
# 105            StackOverflowJobs           23558           23.830863
# 73                           IDE           23457           23.728694
# 14                 HopeFiveYears           23137           23.404987
# 108  StackOverflowConsiderMember           22848           23.112640
# 79                     AdBlocker           22800           23.064084
# 74               OperatingSystem           22676           22.938648
# 75                NumberMonitors           22457           22.717111
# 101       StackOverflowRecommend           22366           22.625057
# 13            CareerSatisfaction           22351           22.609883
# 103      StackOverflowHasAccount           22064           22.319559
# 102           StackOverflowVisit           22044           22.299327
# 11               YearsCodingProf           20952           21.194679
# 65            LanguageWorkedWith           20521           20.758687
# 16                    LastNewJob           19966           20.197259
# 7                 UndergradMajor           19819           20.048556
# 15               JobSearchStatus           19367           19.591321
# 9                        DevType            6757            6.835264
# 10                   YearsCoding            5020            5.078145
# 6                FormalEducation            4152            4.200091
# 4                        Student            3954            3.999798
# 5                     Employment            3534            3.574933
# 3                        Country             412            0.416772
# 1                          Hobby               0            0.000000
# 2                     OpenSource               0            0.000000
# 0                     Respondent               0            0.000000

# %%
l = df.dtypes.to_dict()
print(type(l))
for k,v in l.items():
    print(str(k) + "::" + str(v))
# Out:
# <class 'dict'>
# LastNewJob::object
# SexualOrientation::object
# AIInteresting::object
# PlatformDesireNextYear::object
# CareerSatisfaction::object
# LanguageWorkedWith::object
# LanguageDesireNextYear::object
# DatabaseWorkedWith::object
# HoursComputer::object
# Student::object
# FormalEducation::object
# AdsPriorities4::float64
# Hobby::object
# AssessBenefits8::float64
# JobEmailPriorities5::float64
# AssessBenefits6::float64
# StackOverflowDevStory::object
# EthicsChoice::object
# SurveyEasy::object
# JobContactPriorities2::float64
# AssessJob4::float64
# OperatingSystem::object
# JobContactPriorities3::float64
# EducationParents::object
# SurveyTooLong::object
# AdsPriorities3::float64
# Age::object
# Exercise::object
# AssessBenefits5::float64
# StackOverflowJobs::object
# Employment::object
# OpenSource::object
# AdBlockerDisable::object
# HypotheticalTools3::object
# HypotheticalTools1::object
# StackOverflowParticipate::object
# AssessBenefits4::float64
# AssessJob9::float64
# HypotheticalTools2::object
# Methodology::object
# AdsPriorities5::float64
# AdBlockerReasons::object
# JobSatisfaction::object
# JobSearchStatus::object
# AdsPriorities2::float64
# FrameworkDesireNextYear::object
# AssessJob1::float64
# WakeTime::object
# JobContactPriorities4::float64
# AIDangerous::object
# DatabaseDesireNextYear::object
# AssessJob8::float64
# TimeFullyProductive::object
# HoursOutside::object
# JobEmailPriorities6::float64
# AssessBenefits11::float64
# AdsAgreeDisagree1::object
# Dependents::object
# CurrencySymbol::object
# ErgonomicDevices::object
# AssessJob6::float64
# AdsPriorities6::float64
# StackOverflowConsiderMember::object
# StackOverflowHasAccount::object
# HypotheticalTools4::object
# Currency::object
# AssessJob3::float64
# SkipMeals::object
# AdsPriorities1::float64
# JobContactPriorities5::float64
# AssessJob10::float64
# AssessJob2::float64
# AdsAgreeDisagree3::object
# AdBlocker::object
# StackOverflowVisit::object
# DevType::object
# AdsPriorities7::float64
# NumberMonitors::object
# AIFuture::object
# RaceEthnicity::object
# SalaryType::object
# TimeAfterBootcamp::object
# JobEmailPriorities4::float64
# YearsCodingProf::object
# JobContactPriorities1::float64
# Respondent::int64
# AssessBenefits2::float64
# AgreeDisagree3::object
# UndergradMajor::object
# JobEmailPriorities2::float64
# StackOverflowRecommend::object
# YearsCoding::object
# AssessBenefits3::float64
# AssessBenefits9::float64
# AgreeDisagree1::object
# MilitaryUS::object
# AgreeDisagree2::object
# EducationTypes::object
# CheckInCode::object
# JobEmailPriorities1::float64
# ConvertedSalary::float64
# StackOverflowJobsRecommend::object
# CommunicationTools::object
# AssessJob5::float64
# EthicsResponsible::object
# HypotheticalTools5::object
# Salary::object
# FrameworkWorkedWith::object
# AIResponsible::object
# AssessJob7::float64
# SelfTaughtTypes::object
# AdsAgreeDisagree2::object
# HackathonReasons::object
# JobEmailPriorities3::float64
# Country::object
# HopeFiveYears::object
# JobEmailPriorities7::float64
# AssessBenefits10::float64
# EthicsReport::object
# PlatformWorkedWith::object
# VersionControl::object
# AssessBenefits1::float64
# Gender::object
# AssessBenefits7::float64
# AdsActions::object
# EthicalImplications::object
# IDE::object
# CompanySize::object
# UpdateCV::object

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.infer_objects().dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-82bd82ab0aee> in <module>()
# ----> 1 df.infer_objects().dtypes
#
# c:\users\prana\appdata\local\programs\python\python35-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'infer_objects'

# %%
pd.__version__
# Out:
# '0.19.2'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.23.4'
